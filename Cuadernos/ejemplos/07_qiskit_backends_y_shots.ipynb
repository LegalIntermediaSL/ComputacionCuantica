# %% [markdown]
# # Ejemplo 07: Qiskit, backends y shots
#
# ## Objetivo
#
# Explicar el papel de los `shots` y del backend en la interpretacion de los resultados de un circuito cuantico.

# %% [markdown]
# En computacion cuantica no solemos quedarnos con una sola corrida del circuito. Repetimos la medicion muchas veces y observamos cuentas acumuladas. El numero de repeticiones recibe el nombre de `shots`.

# %%
shots = [16, 128, 1024]
shots

# %% [markdown]
# A mayor numero de `shots`, mejor suele aproximarse la distribucion observada a la prediccion teorica, aunque nunca desaparece del todo la naturaleza estadistica del proceso. El backend, por su parte, determina si estamos en simulacion ideal o en una plataforma mas realista.
