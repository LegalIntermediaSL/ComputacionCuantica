# %% [markdown]
# # Open quantum systems: intuicion
#
# Cuaderno conceptual para conectar sistemas abiertos, canales, decoherencia y dinamica efectiva.

# %%
ideas = [
    "sistema cerrado -> evolucion unitaria",
    "sistema abierto -> descripcion efectiva sobre matrices de densidad",
    "decoherencia y relajacion -> dos mecanismos conceptualmente distintos"
]

for idea in ideas:
    print(idea)
