# %% [markdown]
# # Simulacion hamiltoniana: intuicion
#
# Cuaderno conceptual para relacionar Hamiltonianos, evolucion y coste de simulacion.

# %% [markdown]
# ## Idea central
#
# Simular un Hamiltoniano implica aproximar su evolucion con recursos finitos y precision controlada.

# %%
niveles_precision = ["baja", "media", "alta"]
for nivel in niveles_precision:
    print("Precision", nivel, "-> distinto coste de simulacion y distinta profundidad de circuito")
