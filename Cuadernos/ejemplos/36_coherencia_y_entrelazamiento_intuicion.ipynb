# %% [markdown]
# # Coherencia y entrelazamiento: intuicion
#
# Cuaderno conceptual para distinguir dos recursos cuanticos que suelen confundirse.

# %%
ideas = [
    "coherencia -> fases relativas e interferencia",
    "entrelazamiento -> correlaciones no clasicas entre subsistemas",
    "no toda superposicion implica entrelazamiento"
]

for idea in ideas:
    print(idea)
