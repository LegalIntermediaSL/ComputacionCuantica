# %% [markdown]
# # Shots y estadistica de medicion
#
# Cuaderno conceptual para entender por que el numero de shots cambia la estabilidad de los resultados observados.

# %% [markdown]
# ## Idea central
#
# Los counts medidos no son solo una propiedad del circuito ideal. Tambien dependen del muestreo finito y, por tanto, del numero de shots.

# %%
shots = [16, 64, 256, 1024]
for s in shots:
    print(f"shots = {s}: la estadistica observada suele acercarse mas al valor esperado cuanto mayor es el muestreo")
