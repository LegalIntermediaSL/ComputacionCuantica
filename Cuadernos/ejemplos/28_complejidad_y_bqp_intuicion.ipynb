# %% [markdown]
# # Complejidad cuantica y BQP: intuicion
#
# Cuaderno conceptual para ordenar las ideas de complejidad, oraculos y speedup.

# %% [markdown]
# ## Idea central
#
# Hablar de ventaja cuantica exige hablar de familias de problemas, recursos y comparaciones honestas con algoritmos clasicos.

# %%
ejemplos = {
    "Deutsch-Jozsa": "consulta a un oraculo y separacion en modelo de consultas",
    "Grover": "mejora cuadratica en busqueda no estructurada",
    "QFT / Phase Estimation": "pieza estructural en algoritmos mas profundos"
}

for nombre, idea in ejemplos.items():
    print(f"{nombre}: {idea}")
