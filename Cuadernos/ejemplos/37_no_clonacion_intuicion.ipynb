# %% [markdown]
# # No-clonacion: intuicion
#
# Cuaderno conceptual para remarcar por que copiar un estado cuantico desconocido no se comporta como copiar un bit clasico.

# %%
mensajes = [
    "copiar un estado conocido preparado muchas veces no es lo mismo que clonar un estado arbitrario desconocido",
    "la linealidad de la teoria impone restricciones fuertes",
    "la no-clonacion es un limite estructural, no una simple limitacion tecnica"
]

for m in mensajes:
    print(m)
