# %% [markdown]
# # Ejemplo 20: noise model conceptual
#
# ## Objetivo
#
# Introducir la idea de modelo de ruido como capa de simulación más realista que la ideal, sin perder claridad conceptual.

# %% [markdown]
# Un `noise model` no reemplaza el hardware real, pero permite explorar cómo se degradan los resultados cuando abandonamos la hipótesis de puertas perfectas y mediciones ideales.

# %%
circuit_ideal = 'superposicion + medicion ideal'
circuit_ruidoso = 'superposicion + ruido efectivo + medicion'
circuit_ideal, circuit_ruidoso
