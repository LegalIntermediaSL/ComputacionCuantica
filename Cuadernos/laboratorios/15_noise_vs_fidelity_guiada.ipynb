# %% [markdown]
# # Laboratorio guiado: ruido y fidelidad
#
# Este laboratorio une canales de ruido, matrices de densidad y la idea de fidelidad respecto a un estado objetivo.

# %%
niveles_ruido = [0.0, 0.1, 0.2, 0.3]
for p in niveles_ruido:
    print("Nivel de ruido:", p, "-> discutir como cambia la cercania al estado ideal")
