# %% [markdown]
# # Laboratorio guiado: density matrix, ruido y tomografia
#
# Este laboratorio conecta matrices de densidad, ruido y la necesidad de reconstruccion por mediciones repetidas.

# %% [markdown]
# ## Objetivo
#
# Entender por que la caracterizacion experimental de un estado exige mirar estadisticas en distintas bases y no una sola medicion aislada.

# %%
import numpy as np

rho = 0.5 * np.array([[1, 1], [1, 1]], dtype=complex)
print("Matriz de densidad de partida:\n", rho)
print("Objetivo del laboratorio: pensar como el ruido y las distintas bases afectan a la reconstruccion.")
