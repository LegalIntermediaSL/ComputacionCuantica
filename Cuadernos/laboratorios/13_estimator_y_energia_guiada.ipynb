# %% [markdown]
# # Laboratorio guiado: estimator y energia
#
# Este laboratorio prepara la intuicion necesaria para leer VQE y observables como problemas de estimacion de energia.

# %% [markdown]
# ## Idea central
#
# Un Hamiltoniano sencillo puede tratarse como una cantidad cuyo valor esperado queremos estimar en un estado preparado por un circuito.

# %%
import numpy as np

theta_values = np.linspace(0, np.pi, 5)
print("Barrido conceptual de parametros:", theta_values)
print("Objetivo del laboratorio: relacionar parametros de un circuito con energia esperada.")
