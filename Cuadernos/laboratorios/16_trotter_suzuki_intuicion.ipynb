# %% [markdown]
# # Laboratorio guiado: Trotter-Suzuki e intuicion de coste
#
# Laboratorio conceptual para relacionar precision, numero de pasos y profundidad.

# %%
pasos = [1, 2, 4, 8]
for n in pasos:
    print("Pasos:", n, "-> mas precision potencial, pero tambien mas coste y mas sensibilidad al ruido")
