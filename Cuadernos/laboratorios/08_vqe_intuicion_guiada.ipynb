# %% [markdown]
# # Laboratorio 08: VQE guiado
#
# ## Objetivo
#
# Entender la lógica híbrida de VQE a partir de un circuito parametrizado, un observable y un bucle de optimización conceptual.

# %%
from qiskit import QuantumCircuit
from qiskit.circuit import Parameter
from qiskit.quantum_info import SparsePauliOp

theta = Parameter('theta')
qc = QuantumCircuit(1)
qc.ry(theta, 0)
hamiltonian = SparsePauliOp.from_list([('Z', 1.0)])
qc, hamiltonian

# %% [markdown]
# ## Preguntas de trabajo
#
# 1. Qué papel cumple el ansatz?
# 2. Qué papel cumple el observable?
# 3. Dónde entra la optimización clásica?
